# %%
import pandas as pd

# %%
data = pd.read_csv ("../HW 1/FIFA18_modified.csv")

# %%
data
# Out:
#        Unnamed: 0            Name  Age Nationality  Overall  Potential  \
# 0               0       L. Suárez   30     Uruguay       92         92
# 1               1   R. Nainggolan   29     Belgium       86         86
# 2               2     A. Florenzi   26       Italy       82         83
# 3               3        D. Alaba   25     Austria       85         87
# 4               4        P. Pogba   24      France       88         92
# ...           ...             ...  ...         ...      ...        ...
# 16055       17922      A. Viscovo   18       Italy       51         70
# 16056       17923       A. Kelsey   17     England       46         63
# 16057       17924     A. Giacomel   18       Italy       49         64
# 16058       17925      D. Maekawa   22       Japan       54         61
# 16059       17926        A. Jones   16     England       48         66
#
#                      Club   Value   Wage  Special  ... StandingTackle  \
# ...

# %%
data.loc[:,['Name','Overall','Value']].to_csv('FIFA18_modified_for_linear.csv')

# %%
my_data = pd.read_csv ("FIFA18_modified_for_linear.csv")

# %%
my_data
# Out:
#                  Name  Overall   Value
# 0           L. Suárez       92    €97M
# 1       R. Nainggolan       86  €42.5M
# 2         A. Florenzi       82    €21M
# 3            D. Alaba       85  €38.5M
# 4            P. Pogba       88    €76M
# ...               ...      ...     ...
# 16055      A. Viscovo       51    €60K
# 16056       A. Kelsey       46    €50K
# 16057     A. Giacomel       49    €50K
# 16058      D. Maekawa       54    €70K
# 16059        A. Jones       48    €50K
#
# [16060 rows x 3 columns]

# %%
my_new_data = pd.read_csv ("FIFA18_modified_for_linear2.csv")

# %%
my_new_data
# Out:
#                  Name  Overall     Value
# 0           L. Suárez       92  97000000
# 1       R. Nainggolan       86  42000000
# 2         A. Florenzi       82  21000000
# 3            D. Alaba       85  38000000
# 4            P. Pogba       88  76000000
# ...               ...      ...       ...
# 16055      A. Viscovo       51     60000
# 16056       A. Kelsey       46     50000
# 16057     A. Giacomel       49     50000
# 16058      D. Maekawa       54     70000
# 16059        A. Jones       48     50000
#
# [16060 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
x = pd.DataFrame(my_new_data, columns = ["Overall"])
y = pd.DataFrame(my_new_data, columns = ['Value'])

my_new_data.describe()
# Out:
#             Overall         Value
# count  16060.000000  1.606000e+04
# mean      66.005230  2.251500e+06
# std        7.018907  5.599295e+06
# min       46.000000  4.000000e+03
# 25%       61.000000  3.000000e+05
# 50%       66.000000  6.750000e+05
# 75%       71.000000  1.000000e+06
# max       94.000000  1.190000e+08

# %%
plt.scatter(x, y, alpha = 0.3)

plt.xlabel("Overall")
plt.ylabel("Value")

# plt.xlim(0, 94)
# plt.ylim(0, 1.190000e+08)
# Out:
# Text(0, 0.5, 'Value')

# %%
import sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([[482183.23480357]])

# %%
reg.intercept_
# Out:
# array([-29575115.50150179])

# %%
plt.scatter(x, y, alpha = 0.3)

plt.xlabel("Budget")
plt.ylabel("Revenue")

plt.plot(x, reg.predict(x), color='yellow')

# plt.xlim(0, 94.000000)
# plt.ylim(0, 1.190000e+08)
